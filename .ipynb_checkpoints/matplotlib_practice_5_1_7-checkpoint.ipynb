# %%
# %matplotlib inline

# %%
# Dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis, 'o')

# %%
plt.scatter(y_axis,x_axis, color = 'red', label = 'Chicago')
plt.legend()
plt.title("Scatter Plot Average Fare by Month")
plt.xlabel('Month')
plt.ylabel('Fares ($)')
plt.gca().invert_yaxis()
plt.xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*6)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger , color = 'orange')

# %%
plt.scatter(x_axis, y_axis, s = [i * 8 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
ax.scatter(x_axis, y_axis, s=y_axis)
plt.plot(x, y, linewidth=10, alpha=0.2)

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis, color = "lightblue", s= [i * 5 for i in y_axis], linewidths=3, alpha=0.2, label = "Boston", ec = "k")
ax.set_xlabel("Fares ($)")
ax.set_ylabel("Month")
ax.set_title("Average Fare by Month")
ax.invert_yaxis()
ax.set_xlim(0,50)
ax.legend()
